# %% [markdown]
# # Social Data Analysis and Visualization (02806) - Assignment 2
#
# ## Group 70
#
# | Parts   | Contributor                 |
# | ------- | --------------------------- |
# | Part 1  | Brynjar Bjarkason (s253549) |
# | Par 2:  | Adam Ajane (s211048)        |
# | Part 3: | Sævar Reynisson (s260166)   |
#
# ## Imports

# %% [markdown]
# ### Outline: The fall and rise of drug offenses in San Fransisco
# - Introduction: Drug offenses falling, then rising, Tenderloin neighborhood
# - Visualizations:
#   - One static chart: Time-series plot showing the number of drug offenses over time
#   - One map: Heatmap with time, how crime is distributed over time and concentrate in a few area
#   - One interactive plotly viz:
# - Conclusion
